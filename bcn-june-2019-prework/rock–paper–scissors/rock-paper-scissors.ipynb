# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
outcomes = ["stone", "paper", "scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
num_games_win = 3

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def randomResult(x):
    y = random.choice(x)
    return y

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def askChoice(x):
    x = input("What do you choose? stone, paper or scissors?")
    if x not in outcomes:
        x = input("Wrong answer! You can only choose one of the following: stone, paper or scissors")
    return x

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat(x, y):
    if x == y:
        return "This is a tie"
    elif x == "stone":
        if y == "paper":
            return "Machine wins"
        elif y == "scissors":
            return "Human wins"
    elif x == "paper":
        if y == "stone":
            return "Human wins"
        elif y == "scissors":
            return "Machine wins"
    elif x == "scissors":
        if y == "stone":
            return "Machine wins"
        elif y == "paper":
            return "Human wins"

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def status(x,y,i,j):
    print("These are the respective choices of Human and Machine", x, y)
    print("These are the respective number of wins for Human vs Machine so far", i, j)

# Create two variables that accumulate the wins of each participant
human_wins = 0
machine_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while human_wins < num_games_win and machine_wins < num_games_win:
    human = askChoice(outcomes)
    print("Human chose", human)
    machine = randomResult(outcomes)
    print("Machine chose", machine)
    result = combat(human,machine)
    print(result)
    if result == "Human wins":
        human_wins +=1
    elif result == "Machine wins":
        machine_wins +=1
    status(human,machine,human_wins,machine_wins)
    
# Print by console the winner of the game based on who has more accumulated wins
if human_wins == 3:
    print("Human wins the game")
elif machine_wins == 3:
    print("Machine wins the game")
# Out:
# What do you choose? stone, paper or scissors?ht
# Wrong answer! You can only choose one of the following: stone, paper or scissorsho
# Human chose ho
# Machine chose scissors
# None
# These are the respective choices of Human and Machine ho scissors
# These are the respective number of wins for Human vs Machine so far 0 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e62cba1c93e3> in <module>
#      64 # that accumulate the wins of each participant.
#      65 while human_wins < num_games_win and machine_wins < num_games_win:
# ---> 66     human = askChoice(outcomes)
#      67     print("Human chose", human)
#      68     machine = randomResult(outcomes)
#
# <ipython-input-1-e62cba1c93e3> in askChoice(x)
#      23 # If it is not stone, paper or scissors keep asking until it is.
#      24 def askChoice(x):
# ---> 25     x = input("What do you choose? stone, paper or scissors?")
#      26     if x not in outcomes:
#      27         x = input("Wrong answer! You can only choose one of the following: stone, paper or scissors")
#
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# /home/linuxbrew/.linuxbrew/Cellar/ipython/7.5.0/libexec/vendor/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def oddNumber(x):
    x = input("Choose an odd number for the total number of games")
   
    if int(x) % 2 == 0:
        x = input("Wrong answer! You can only choose an ODD number!")
    return x

# Assign a list of 5 possible options.
outcomes = ["stone", "paper", "scissors", "lizard", "spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
k = int
max_games = oddNumber(k)

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
num_games_win = (int(max_games) +1)/2
print("The number of games to win in order to win the match are", num_games_win)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def randomResult(x):
    y = random.choice(x)
    return y

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def askChoice(x):
    x = input("What do you choose? stone, paper, scissors, lizard or spock?")
    if x not in outcomes:
        x = input("Wrong answer! You can only choose one of the following: stone, paper scissors, lizard or spock?")
    return x


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combat(x, y):
    if x == y:
        return 0
    elif x == "stone":
        if y == "paper":
            return 1
        elif y == "scissors":
            return 2
        elif y == "spock":
            return 1
        elif y == "lizard":
            return 2
    elif x == "paper":
        if y == "stone":
            return 2
        elif y == "scissors":
            return 1
        elif y == "spock":
            return 2
        elif y == "lizard":
            return 1
    elif x == "scissors":
        if y == "stone":
            return 1
        elif y == "paper":
            return 2
        elif y == "spock":
            return 1
        elif y == "lizard":
            return 2
    elif x == "spock":
        if y == "stone":
            return 2
        elif y == "paper":
            return 1
        elif y == "scissors":
            return 2
        elif y == "lizard":
            return 1
    elif x == "lizard":
        if y == "stone":
            return 1
        elif y == "paper":
            return 2
        elif y == "scissors":
            return 1
        elif y == "spock":
            return 2

        
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def status(x,y,i,j):
    print("These are the respective choices of Human and Machine", x, y)
    print("These are the respective number of wins for Human vs Machine so far", i, j)
    
# Create two variables that accumulate the wins of each participant
human_wins = 0
machine_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while human_wins < num_games_win and machine_wins < num_games_win:
    human = askChoice(outcomes)
    print("Human chose", human)
    machine = randomResult(outcomes)
    print("Machine chose", machine)
    result = combat(human,machine)
    print(result)
    if result == 2:
        human_wins +=1
    elif result == 1:
        machine_wins +=1
    status(human,machine,human_wins,machine_wins)
    
    
# Print by console the winner of the game based on who has more accumulated wins
if human_wins == num_games_win:
    print("Human wins the game")
elif machine_wins == num_games_win:
    print("Machine wins the game")
# Out:
# Choose an odd number for the total number of games5
# 3.0
# What do you choose? stone, paper, scissors, lizard or spock?stone
# Human chose stone
# Machine chose lizard
# 2
# These are the respective choices of Human and Machine stone lizard
# These are the respective number of wins for Human vs Machine so far 1 0
# What do you choose? stone, paper, scissors, lizard or spock?paper
# Human chose paper
# Machine chose lizard
# 1
# These are the respective choices of Human and Machine paper lizard
# These are the respective number of wins for Human vs Machine so far 1 1
# What do you choose? stone, paper, scissors, lizard or spock?stone
# Human chose stone
# Machine chose spock
# 1
# These are the respective choices of Human and Machine stone spock
# These are the respective number of wins for Human vs Machine so far 1 2
# What do you choose? stone, paper, scissors, lizard or spock?lizard
# Human chose lizard
# Machine chose scissors
# 1
# These are the respective choices of Human and Machine lizard scissors
# These are the respective number of wins for Human vs Machine so far 1 3
# Machine wins the game
